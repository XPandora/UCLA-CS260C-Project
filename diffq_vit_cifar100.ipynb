# %%
# !git clone https://github.com/facebookresearch/diffq.git
# !git clone https://github.com/Eurus-Holmes/diffq.git
# Out:
# Cloning into 'diffq'...
# remote: Enumerating objects: 493, done.
# remote: Counting objects: 100% (493/493), done.
# remote: Compressing objects: 100% (305/305), done.
# remote: Total 493 (delta 297), reused 350 (delta 182), pack-reused 0
# Receiving objects: 100% (493/493), 182.11 KiB | 5.69 MiB/s, done.
# Resolving deltas: 100% (297/297), done.

# %%
# %cd diffq/
# Out:
# /content/diffq

# %%
# !pip install .
# Out:
# Processing /content/diffq
#   DEPRECATION: A future pip version will change local packages to be built in-place without first copying to a temporary directory. We recommend you use --use-feature=in-tree-build to test your packages with this new behavior before it becomes the default.
#    pip 21.3 will remove support for this functionality. You can find discussion regarding this at https://github.com/pypa/pip/issues/7555.
# ...
#   Created wheel for diffq: filename=diffq-0.2.3a1-cp37-cp37m-linux_x86_64.whl size=309601 sha256=1d9308c55b79abdc7e99632d4f4f3eb748f3e4963bf3cf2d9e1355af3b01509e
#   Stored in directory: /tmp/pip-ephem-wheel-cache-4qp3sac2/wheels/4e/49/91/12e45240328398fc41817120437abb4845c605b67fb43bfa69
# Successfully built diffq
# ...

# %%
# %cd examples/cifar/
# Out:
# /content/diffq/examples/cifar

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      |████████████████████████████████| 123 kB 14.3 MB/s
# ...
#      |████████████████████████████████| 70 kB 10.4 MB/s
# ...
#      |████████████████████████████████| 112 kB 75.8 MB/s
# ...
#      |████████████████████████████████| 596 kB 50.0 MB/s
# ...
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.8-py3-none-any.whl size=141230 sha256=8c3ec27402d7b1b8cab8c2bc7af742a624679dda5ffd66e742b5eae68ccbc7b5
#   Stored in directory: /root/.cache/pip/wheels/ca/33/b7/336836125fc9bb4ceaa4376d8abca10ca8bc84ddc824baea6c
# Successfully built antlr4-python3-runtime
# ...
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...

# %%
# !./train.py db.name=cifar10 model=resnet quant.penalty=5 quant.group_size=16
# Out:
# [02-24 03:03:02][__main__][INFO] - For logs, checkpoints and samples check /content/diffq/examples/cifar/outputs/exp_db.name=cifar10,model=resnet,quant.group_size=16,quant.penalty=5
# [02-24 03:03:08][numexpr.utils][INFO] - NumExpr defaulting to 2 threads.
# [02-24 03:03:08][__main__][INFO] - Running on host eea3441f837a
# ...
# 170499072it [00:03, 48793802.08it/s]
# Extracting /content/diffq/examples/cifar/data/cifar10/cifar-10-python.tar.gz to /content/diffq/examples/cifar/data/cifar10
# Files already downloaded and verified
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 5 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# ...

# %%
# !pip install einops

# %%
# !./train.py db.name=cifar100 model=vit quant.penalty=5 quant.group_size=16
# Out:
# [03-14 14:48:07][__main__][INFO] - For logs, checkpoints and samples check /content/diffq/examples/cifar/outputs/exp_db.name=cifar100,model=vit,quant.group_size=16,quant.penalty=5
# [03-14 14:48:08][numexpr.utils][INFO] - NumExpr defaulting to 2 threads.
# [03-14 14:48:08][__main__][INFO] - Running on host caa6edc69db3
# ...
# 169001984it [00:05, 28875399.62it/s]
# Extracting /content/diffq/examples/cifar/data/cifar100/cifar-100-python.tar.gz to /content/diffq/examples/cifar/data/cifar100
# Files already downloaded and verified
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 5 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# ...
